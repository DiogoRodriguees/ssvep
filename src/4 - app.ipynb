# %% [markdown]
# # Simulação de aplicação
#
# O paradigma SSVEP é bastante utilizado em aplicações reais por ser fácil de evocar os sinais e posteriormente classificá-los.
#
# Para processar uma aplicação SSVEP em tempo real é necessário calcular a máxima energia dos _targets_ em janelas ou _buffers_ suficientemente grandes. O tamanho da janela de dados é inversamente proporcional a taxa de amostragem do equipamente de EEG utilizado. Ou seja, quanto maior a taxa de amostragem, menor o tempo decessário para calcular a **energia deslizante do sinal**.
#
# **Tarefa**: simule uma aplicação SSVEP criando um buffer do sinal no domínio do tempo em uma única dimensão. Se inicialmente a dimensão dos dados era `(100, 8192)`, agora será `(819200)`. Crie um buffer de 3 ou 4 segundos, informando a cada segundo qual está sendo a frequência evocada.

# %%
import mne
# %store -r data7
# %store -r sfreq
# %store -r values
# %store -r info
buffer = data7.reshape(819200)
buffer_size = buffer.shape[0]
buffer.shape

buffer_length = 4 * sfreq 
window_length = sfreq 
step = sfreq 

evoked_freqs = []

for start in range(0, buffer_size - buffer_length + 1, step):
    end = start + buffer_length
    segment = buffer[start:end].reshape(1, -1)
    
    segment_epochs = mne.EpochsArray(segment.reshape(1, 1, -1), info)
    
    psd = segment_epochs.compute_psd(method='multitaper', fmin=3, fmax=13, verbose=False)
    psd_df = psd.to_data_frame()
    
    freq = psd_df['freq'][psd_df['Oz'] == psd_df['Oz'].max()].values[0]
    closest_freq = min(values, key=lambda x: abs(x - freq))
    evoked_freqs.append(closest_freq)
    
    print(f"Segundo {start // sfreq + 1}: Frequência evocada = {closest_freq} Hz")
# Out:
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 1: Frequência evocada = 7.5 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 2: Frequência evocada = 6.5 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 3: Frequência evocada = 7 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 4: Frequência evocada = 6.5 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 5: Frequência evocada = 6.5 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 6: Frequência evocada = 6.5 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 7: Frequência evocada = 6.5 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 8: Frequência evocada = 6.5 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 9: Frequência evocada = 7.5 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 10: Frequência evocada = 6.5 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 11: Frequência evocada = 6.5 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 12: Frequência evocada = 6.5 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 13: Frequência evocada = 6.5 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 14: Frequência evocada = 6.5 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 15: Frequência evocada = 7 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 16: Frequência evocada = 6.5 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 17: Frequência evocada = 6 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 18: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 19: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 20: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 21: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 22: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 23: Frequência evocada = 6 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 24: Frequência evocada = 6 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 25: Frequência evocada = 7.5 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 26: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 27: Frequência evocada = 9.3 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 28: Frequência evocada = 8.2 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 29: Frequência evocada = 9.3 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 30: Frequência evocada = 9.3 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 31: Frequência evocada = 7.5 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 32: Frequência evocada = 6.5 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 33: Frequência evocada = 6.5 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 34: Frequência evocada = 7.5 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 35: Frequência evocada = 9.3 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 36: Frequência evocada = 9.3 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 37: Frequência evocada = 9.3 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 38: Frequência evocada = 6.5 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 39: Frequência evocada = 6.5 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 40: Frequência evocada = 6.5 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 41: Frequência evocada = 6.5 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 42: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 43: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 44: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 45: Frequência evocada = 9.3 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 46: Frequência evocada = 6 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 47: Frequência evocada = 6 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 48: Frequência evocada = 6 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 49: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 50: Frequência evocada = 6 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 51: Frequência evocada = 6 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 52: Frequência evocada = 6 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 53: Frequência evocada = 6 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 54: Frequência evocada = 8.2 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 55: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 56: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 57: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 58: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 59: Frequência evocada = 6 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 60: Frequência evocada = 6.5 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 61: Frequência evocada = 6 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 62: Frequência evocada = 6 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 63: Frequência evocada = 6 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 64: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 65: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 66: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 67: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 68: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 69: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 70: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 71: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 72: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 73: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 74: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 75: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 76: Frequência evocada = 6.5 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 77: Frequência evocada = 6 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 78: Frequência evocada = 6.5 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 79: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 80: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 81: Frequência evocada = 7 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 82: Frequência evocada = 7 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 83: Frequência evocada = 7 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 84: Frequência evocada = 7 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 85: Frequência evocada = 7 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 86: Frequência evocada = 7.5 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 87: Frequência evocada = 7 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 88: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 89: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 90: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 91: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 92: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 93: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 94: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 95: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 96: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 97: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 98: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 99: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 100: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 101: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 102: Frequência evocada = 6 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 103: Frequência evocada = 6.5 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 104: Frequência evocada = 8.2 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 105: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 106: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 107: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 108: Frequência evocada = 6.5 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 109: Frequência evocada = 6.5 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 110: Frequência evocada = 6.5 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 111: Frequência evocada = 6 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 112: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 113: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 114: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 115: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 116: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 117: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 118: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 119: Frequência evocada = 6.5 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 120: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 121: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 122: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 123: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 124: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 125: Frequência evocada = 6.5 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 126: Frequência evocada = 6 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 127: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 128: Frequência evocada = 6.5 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 129: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 130: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 131: Frequência evocada = 7.5 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 132: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 133: Frequência evocada = 7.5 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 134: Frequência evocada = 7.5 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 135: Frequência evocada = 7.5 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 136: Frequência evocada = 8.2 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 137: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 138: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo 139: Frequência evocada = 10 Hz
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Segundo